# %% [markdown]
# # Le AI
#
# Generative KI Selbstgemacht
#
# In dieser kleinen Session spreche ich über AI. Ich versuche, folgende Fragen zu beantworten:
#
# - Künstliche Intelligenz: wie funktioniert sie?
# - Ein bißchen Computergeschichte
# - Wir spielen ein bißchen mit Python
#
# Ich bin jedoch noch selbst sehr unerfahren mit dem Thema, so wird es teilweise eine Pull Session.
#
#
# Zu mir:
#
# Ich bin Frontendentwicklerin aus Hamburg, ü40 und seit April 2024 bei adesso. Mein
# Schwerpunkt liegt auf Web Standards und Barrierefreiheit. Besonders interessiere ich mich für Frontend Architektur und Web-Performance. KI/ML ist für mich noch Neuland, perfekt um mal mit einem
# unbedarften Blick darauf drüber zu sprechen.
